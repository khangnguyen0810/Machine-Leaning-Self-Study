# %%
# download data

import numpy as np
from urllib import request
import gzip
import pickle

filenames = ["train-images-idx3-ubyte.gz",
             "train-labels-idx1-ubyte.gz",
             "t10k-images-idx3-ubyte.gz",
             "t10k-labels-idx1-ubyte.gz"]

def download_fashion_mnist(folder):
    base_url = "http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/"
    for name in filenames:        
        # lưu vào folder data_fashion_mnist
        data_path = base_url + name
        saving_path = folder + name
        print(data_path)
        print(saving_path)
        print()

# download dataset và lưu vào folder 'data_fashion_mnist/'
folder = 'data_fashion_mnist/'
download_fashion_mnist(folder)
# Out:
# http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# data_fashion_mnist/train-images-idx3-ubyte.gz
#
# http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# data_fashion_mnist/train-labels-idx1-ubyte.gz
#
# http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# data_fashion_mnist/t10k-images-idx3-ubyte.gz
#
# http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# data_fashion_mnist/t10k-labels-idx1-ubyte.gz

# %%
import urllib.request as req
from PIL import Image
import matplotlib.pyplot as plt
  
# download an image
# https://www.dropbox.com/s/zwy8ddkdm3thatr/nature.jpg?dl=1
req.urlretrieve('https://www.dropbox.com/s/zwy8ddkdm3thatr/nature.jpg?dl=1',
                'image1.jpg')

# show the image
img = Image.open('image1.jpg')
plt.imshow(img)

# %%
import numpy as np
from urllib import request
import gzip
import pickle

filenames = ["t10k-images-idx3-ubyte.gz",
             "t10k-labels-idx1-ubyte.gz"]

def download_fashion_mnist(folder):
    base_url = "http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/"
    for name in filenames:
        print("Downloading " + name + "...")
        
        # lưu vào folder data_fashion_mnist
        request.urlretrieve(base_url + name, folder + name)
    print("Download complete.")

# download dataset và lưu vào folder 'data_fashion_mnist/'
folder = 'data_fashion_mnist/'
download_fashion_mnist(folder)
# Out:
# Downloading t10k-images-idx3-ubyte.gz...
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1278         """Send a complete request to the server."""
# -> 1279         self._send_request(method, url, body, headers, encode_chunked)
#    1280
#
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1324             body = _encode(body, 'body')
# -> 1325         self.endheaders(body, encode_chunked=encode_chunked)
#    1326
#
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1273             raise CannotSendHeader()
# -> 1274         self._send_output(message_body, encode_chunked=encode_chunked)
#    1275
#
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1033         del self._buffer[:]
# -> 1034         self.send(msg)
#    1035
#
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\http\client.py in send(self, data)
#     973             if self.auto_open:
# --> 974                 self.connect()
#     975             else:
#
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\http\client.py in connect(self)
#     944         """Connect to the host and port specified in __init__."""
# --> 945         self.sock = self._create_connection(
#     946             (self.host,self.port), self.timeout, self.source_address)
#
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\socket.py in create_connection(address, timeout, source_address)
#     843         try:
# --> 844             raise err
#     845         finally:
#
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\socket.py in create_connection(address, timeout, source_address)
#     831                 sock.bind(source_address)
# --> 832             sock.connect(sa)
#     833             # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# C:\Users\DINHVI~1\AppData\Local\Temp/ipykernel_26976/780892660.py in <module>
#      18 # download dataset và lưu vào folder 'data_fashion_mnist/'
#      19 folder = 'data_fashion_mnist/'
# ---> 20 download_fashion_mnist(folder)
#
# C:\Users\DINHVI~1\AppData\Local\Temp/ipykernel_26976/780892660.py in download_fashion_mnist(folder)
#      13
#      14         # lưu vào folder data_fashion_mnist
# ---> 15         request.urlretrieve(base_url + name, folder + name)
#      16     print("Download complete.")
#      17
#
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     237     url_type, path = _splittype(url)
#     238
# --> 239     with contextlib.closing(urlopen(url, data)) as fp:
#     240         headers = fp.info()
#     241
#
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\urllib\request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\urllib\request.py in http_open(self, req)
#    1373
#    1374     def http_open(self, req):
# -> 1375         return self.do_open(http.client.HTTPConnection, req)
#    1376
#    1377     http_request = AbstractHTTPHandler.do_request_
#
# E:\SoftInstallation\anaconda\envs\tensorflow_env\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#    1348             except OSError as err: # timeout error
# -> 1349                 raise URLError(err)
#    1350             r = h.getresponse()
#    1351         except:
#
# URLError: <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>

# %%
import numpy as np
import gzip

# load training images
with gzip.open('data_fashion_mnist/train-images-idx3-ubyte.gz', 'rb') as f:
    X_train = np.frombuffer(f.read(), np.uint8, offset=16).reshape(-1, 28*28)

# load testing images
with gzip.open('data_fashion_mnist/t10k-images-idx3-ubyte.gz', 'rb') as f:
    X_test = np.frombuffer(f.read(), np.uint8, offset=16).reshape(-1, 28*28)

# load training labels
with gzip.open('data_fashion_mnist/train-labels-idx1-ubyte.gz', 'rb') as f:
    y_train = np.frombuffer(f.read(), np.uint8, offset=8)
    
# load testing labels
with gzip.open('data_fashion_mnist/t10k-labels-idx1-ubyte.gz', 'rb') as f:
    y_test = np.frombuffer(f.read(), np.uint8, offset=8)
    

# check data
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
import matplotlib.pyplot as plt 
import numpy as np 

# Tạo dang sách 144 phần tử ngẫu nhiên từ X_train có 60.000 phần tử
indices = list(np.random.randint(X_train.shape[0], size=144))

fig =plt.figure(figsize=(9,9))
columns = 12
rows = 12
for i in range(1, columns*rows +1):
    img = X_train[indices[i-1]].reshape(28,28)
    fig.add_subplot(rows, columns, i)
    plt.axis('off')
    plt.imshow(img, cmap='gray', vmin=0, vmax=255)

# %%
from PIL import Image

indices = list(np.random.randint(60000, size=10))
for i in range(10):
    im = Image.fromarray(X_train[indices[i]].reshape(28,28))
    im.save("data_fashion_mnist/images/image_" + str(i) +".png")

# %% [markdown]
# # training

# %%
import numpy as np
import gzip

# load training images
with gzip.open('data_fashion_mnist/train-images-idx3-ubyte.gz', 'rb') as f:
    X_train = np.frombuffer(f.read(), np.uint8, offset=16).reshape(-1, 28*28)

# load testing images
with gzip.open('data_fashion_mnist/t10k-images-idx3-ubyte.gz', 'rb') as f:
    X_test = np.frombuffer(f.read(), np.uint8, offset=16).reshape(-1, 28*28)

# load training labels
with gzip.open('data_fashion_mnist/train-labels-idx1-ubyte.gz', 'rb') as f:
    y_train = np.frombuffer(f.read(), np.uint8, offset=8)
    
# load testing labels
with gzip.open('data_fashion_mnist/t10k-labels-idx1-ubyte.gz', 'rb') as f:
    y_test = np.frombuffer(f.read(), np.uint8, offset=8)
    

# check data
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)

# %%
import tensorflow as tf
import tensorflow.keras as keras

# create model
model = keras.Sequential()
model.add(keras.Input(shape=(784,)))
model.add(keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 10)                7850
#
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
# optimizer and loss
opt = tf.keras.optimizers.SGD(0.05)
model.compile(optimizer=opt, 
              loss='sparse_categorical_crossentropy', 
              metrics=['sparse_categorical_accuracy'])

# training
history = model.fit(X_train, y_train, 256, epochs=50, verbose=2)

# testing
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/50
# 235/235 - 1s - loss: 1301.1735 - sparse_categorical_accuracy: 0.8131 - 562ms/epoch - 2ms/step
# Epoch 2/50
# 235/235 - 0s - loss: 625.8741 - sparse_categorical_accuracy: 0.8604 - 385ms/epoch - 2ms/step
# Epoch 3/50
# 235/235 - 0s - loss: 640.1555 - sparse_categorical_accuracy: 0.8604 - 389ms/epoch - 2ms/step
# Epoch 4/50
# 235/235 - 0s - loss: 606.4131 - sparse_categorical_accuracy: 0.8706 - 359ms/epoch - 2ms/step
# Epoch 5/50
# 235/235 - 0s - loss: 576.6553 - sparse_categorical_accuracy: 0.8741 - 366ms/epoch - 2ms/step
# Epoch 6/50
# 235/235 - 0s - loss: 579.0832 - sparse_categorical_accuracy: 0.8731 - 354ms/epoch - 2ms/step
# Epoch 7/50
# 235/235 - 0s - loss: 541.0535 - sparse_categorical_accuracy: 0.8772 - 412ms/epoch - 2ms/step
# Epoch 8/50
# 235/235 - 0s - loss: 568.6589 - sparse_categorical_accuracy: 0.8744 - 499ms/epoch - 2ms/step
# Epoch 9/50
# 235/235 - 0s - loss: 508.9512 - sparse_categorical_accuracy: 0.8798 - 442ms/epoch - 2ms/step
# Epoch 10/50
# 235/235 - 0s - loss: 571.9289 - sparse_categorical_accuracy: 0.8763 - 369ms/epoch - 2ms/step
# Epoch 11/50
# 235/235 - 1s - loss: 550.8438 - sparse_categorical_accuracy: 0.8790 - 523ms/epoch - 2ms/step
# Epoch 12/50
# 235/235 - 0s - loss: 543.0623 - sparse_categorical_accuracy: 0.8792 - 424ms/epoch - 2ms/step
# Epoch 13/50
# 235/235 - 0s - loss: 494.3108 - sparse_categorical_accuracy: 0.8838 - 396ms/epoch - 2ms/step
# Epoch 14/50
# 235/235 - 0s - loss: 494.1920 - sparse_categorical_accuracy: 0.8827 - 375ms/epoch - 2ms/step
# Epoch 15/50
# 235/235 - 0s - loss: 531.1564 - sparse_categorical_accuracy: 0.8782 - 367ms/epoch - 2ms/step
# Epoch 16/50
# 235/235 - 0s - loss: 524.1061 - sparse_categorical_accuracy: 0.8818 - 363ms/epoch - 2ms/step
# Epoch 17/50
# 235/235 - 0s - loss: 494.8322 - sparse_categorical_accuracy: 0.8834 - 371ms/epoch - 2ms/step
# Epoch 18/50
# 235/235 - 0s - loss: 521.6035 - sparse_categorical_accuracy: 0.8813 - 358ms/epoch - 2ms/step
# Epoch 19/50
# 235/235 - 0s - loss: 499.8330 - sparse_categorical_accuracy: 0.8837 - 405ms/epoch - 2ms/step
# Epoch 20/50
# 235/235 - 0s - loss: 520.0342 - sparse_categorical_accuracy: 0.8813 - 373ms/epoch - 2ms/step
# Epoch 21/50
# 235/235 - 0s - loss: 483.3031 - sparse_categorical_accuracy: 0.8835 - 405ms/epoch - 2ms/step
# Epoch 22/50
# 235/235 - 0s - loss: 544.3561 - sparse_categorical_accuracy: 0.8844 - 401ms/epoch - 2ms/step
# Epoch 23/50
# 235/235 - 0s - loss: 509.8994 - sparse_categorical_accuracy: 0.8838 - 458ms/epoch - 2ms/step
# Epoch 24/50
# 235/235 - 0s - loss: 483.2110 - sparse_categorical_accuracy: 0.8861 - 352ms/epoch - 1ms/step
# Epoch 25/50
# 235/235 - 0s - loss: 556.6866 - sparse_categorical_accuracy: 0.8825 - 369ms/epoch - 2ms/step
# Epoch 26/50
# 235/235 - 0s - loss: 515.4662 - sparse_categorical_accuracy: 0.8882 - 349ms/epoch - 1ms/step
# Epoch 27/50
# 235/235 - 1s - loss: 459.6798 - sparse_categorical_accuracy: 0.8931 - 509ms/epoch - 2ms/step
# Epoch 28/50
# 235/235 - 0s - loss: 479.8352 - sparse_categorical_accuracy: 0.8838 - 378ms/epoch - 2ms/step
# Epoch 29/50
# 235/235 - 0s - loss: 443.1608 - sparse_categorical_accuracy: 0.8853 - 479ms/epoch - 2ms/step
# Epoch 30/50
# 235/235 - 0s - loss: 492.4876 - sparse_categorical_accuracy: 0.8853 - 365ms/epoch - 2ms/step
# Epoch 31/50
# 235/235 - 0s - loss: 449.6765 - sparse_categorical_accuracy: 0.8842 - 349ms/epoch - 1ms/step
# Epoch 32/50
# 235/235 - 0s - loss: 461.5797 - sparse_categorical_accuracy: 0.8901 - 500ms/epoch - 2ms/step
# Epoch 33/50
# 235/235 - 0s - loss: 462.4363 - sparse_categorical_accuracy: 0.8878 - 412ms/epoch - 2ms/step
# Epoch 34/50
# 235/235 - 0s - loss: 479.2490 - sparse_categorical_accuracy: 0.8848 - 365ms/epoch - 2ms/step
# Epoch 35/50
# 235/235 - 0s - loss: 490.8059 - sparse_categorical_accuracy: 0.8844 - 357ms/epoch - 2ms/step
# Epoch 36/50
# 235/235 - 0s - loss: 496.6693 - sparse_categorical_accuracy: 0.8879 - 447ms/epoch - 2ms/step
# Epoch 37/50
# 235/235 - 0s - loss: 477.3601 - sparse_categorical_accuracy: 0.8886 - 377ms/epoch - 2ms/step
# Epoch 38/50
# 235/235 - 0s - loss: 483.7888 - sparse_categorical_accuracy: 0.8891 - 364ms/epoch - 2ms/step
# Epoch 39/50
# 235/235 - 1s - loss: 510.4112 - sparse_categorical_accuracy: 0.8849 - 501ms/epoch - 2ms/step
# Epoch 40/50
# 235/235 - 0s - loss: 460.2519 - sparse_categorical_accuracy: 0.8896 - 358ms/epoch - 2ms/step
# Epoch 41/50
# 235/235 - 0s - loss: 471.6673 - sparse_categorical_accuracy: 0.8857 - 363ms/epoch - 2ms/step
# Epoch 42/50
# 235/235 - 0s - loss: 454.4720 - sparse_categorical_accuracy: 0.8896 - 368ms/epoch - 2ms/step
# Epoch 43/50
# 235/235 - 0s - loss: 487.9869 - sparse_categorical_accuracy: 0.8855 - 361ms/epoch - 2ms/step
# Epoch 44/50
# 235/235 - 0s - loss: 469.1189 - sparse_categorical_accuracy: 0.8877 - 374ms/epoch - 2ms/step
# Epoch 45/50
# 235/235 - 0s - loss: 476.9099 - sparse_categorical_accuracy: 0.8860 - 384ms/epoch - 2ms/step
# Epoch 46/50
# 235/235 - 0s - loss: 445.1830 - sparse_categorical_accuracy: 0.8898 - 391ms/epoch - 2ms/step
# Epoch 47/50
# 235/235 - 0s - loss: 501.5840 - sparse_categorical_accuracy: 0.8867 - 382ms/epoch - 2ms/step
# Epoch 48/50
# 235/235 - 1s - loss: 462.4683 - sparse_categorical_accuracy: 0.8884 - 524ms/epoch - 2ms/step
# Epoch 49/50
# 235/235 - 1s - loss: 418.9102 - sparse_categorical_accuracy: 0.8918 - 532ms/epoch - 2ms/step
# Epoch 50/50
# 235/235 - 0s - loss: 462.1390 - sparse_categorical_accuracy: 0.8873 - 401ms/epoch - 2ms/step
# 313/313 [==============================] - 1s 1ms/step - loss: 562.3936 - sparse_categorical_accuracy: 0.8376
# Test accuracy: 0.8375999927520752

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.xlabel('iteration')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['sparse_categorical_accuracy'])
plt.xlabel('iteration')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')
